# %%
from sklearn import datasets
faces = datasets.fetch_olivetti_faces()

# %% [raw]
# # Al ejecutar este código, faces contendrá un objeto que proporciona acceso
# # al conjunto de datos de caras Olivetti, incluyendo las imágenes y las etiquetas asociadas a cada persona.

# %%
import time
import numpy as np

from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.image import extract_patches_2d

# %% [raw]
# # MiniBatchKMeans: Es una versión del algoritmo K-Means que utiliza mini lotes para acelerar el proceso de clustering en grandes conjuntos de datos.
# # extract_patches_2d: Esta función se utiliza para extraer parches (pequeñas sub-regiones) de una imagen 2D. Es útil para la extracción de características de imágenes en tareas de procesamiento de imágenes y aprendizaje automático.

# %%
print("Learning the dictionary... ")
rng = np.random.RandomState(0)
kmeans = MiniBatchKMeans(n_clusters=81, random_state=rng, verbose=True, n_init=3)
patch_size = (10, 10)
# Out:
# Learning the dictionary...

# %% [raw]
# # crea una instancia de MiniBatchKMeans con los parámetros
# # Además, se define patch_size como un par de valores (20, 20), que representa el tamaño de los parches (sub-regiones) que se extraerán de la imagen para el aprendizaje del diccionario. En este caso, los parches serán de 20x20 píxeles.

# %%
buffer = []
t0 = time.time()
index = 0
for _ in range(6):
    for img in faces.images:
        data = extract_patches_2d(img, patch_size, max_patches=500, random_state=rng)
        data = np.reshape(data, (len(data), -1))
        buffer.append(data)
        index += 1
        if index % 10 == 0:
            data = np.concatenate(buffer, axis=0)
            data -= np.mean(data, axis=0)
            data /= np.std(data, axis=0)
            kmeans.partial_fit(data)
            buffer = []
        if index % 100 == 0:
            print("Partial fit of %4i out of %i" % (index, 6 * len(faces.images)))

dt = time.time() - t0
print("done in %.2fs." % dt)
# Out:
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# [MiniBatchKMeans] Reassigning 2 cluster centers.
# [MiniBatchKMeans] Reassigning 2 cluster centers.
# Partial fit of  100 out of 2400
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Partial fit of  200 out of 2400
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Partial fit of  300 out of 2400
# Partial fit of  400 out of 2400
# Partial fit of  500 out of 2400
# Partial fit of  600 out of 2400
# Partial fit of  700 out of 2400
# Partial fit of  800 out of 2400
# Partial fit of  900 out of 2400
# Partial fit of 1000 out of 2400
# Partial fit of 1100 out of 2400
# Partial fit of 1200 out of 2400
# Partial fit of 1300 out of 2400
# Partial fit of 1400 out of 2400
# Partial fit of 1500 out of 2400
# ...

# %% [raw]
# # La parte de aprendizaje en línea: recorre todo el conjunto de datos 6 veces

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4.2, 4))
for i, patch in enumerate(kmeans.cluster_centers_):
    plt.subplot(9, 9, i + 1)
    plt.imshow(patch.reshape(patch_size), cmap=plt.cm.gray, interpolation="nearest")
    plt.xticks(())
    plt.yticks(())

plt.suptitle(
    "Patches of faces\nTrain time %.1fs on %d patches" % (dt, 8 * len(faces.images)),
    fontsize=16,
)
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)

plt.show()

# %% [raw]
# # Graficar los resultados
